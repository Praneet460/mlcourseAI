# %% [markdown]
# ### Assignnment 1 (Python)

# %% [markdown]
# #### Import required libraries

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Import Dataset

# %%
cwd = os.getcwd()
path = os.path.join(cwd, "athlete_events.csv")
data = pd.read_csv(path)
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.shape
# Out:
# (271116, 15)

# %%
list(data)
# Out:
# ['ID',
#  'Name',
#  'Sex',
#  'Age',
#  'Height',
#  'Weight',
#  'Team',
#  'NOC',
#  'Games',
#  'Year',
#  'Season',
#  'City',
#  'Sport',
#  'Event',
#  'Medal']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
# ID        271116 non-null int64
# Name      271116 non-null object
# Sex       271116 non-null object
# Age       261642 non-null float64
# Height    210945 non-null float64
# Weight    208241 non-null float64
# Team      271116 non-null object
# NOC       271116 non-null object
# Games     271116 non-null object
# Year      271116 non-null int64
# Season    271116 non-null object
# City      271116 non-null object
# Sport     271116 non-null object
# Event     271116 non-null object
# Medal     39783 non-null object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# ### Questions

# %% [markdown]
# #### 1. How old were the youngest male and female participants of the 1996 Olympics?

# %%
data['Year'].head()
# Out:
# 0    1992
# 1    2012
# 2    1920
# 3    1900
# 4    1988
# Name: Year, dtype: int64

# %%
year_1996 = data[data['Year'] == 1996]
year_1996.head()
# Out:
#      ID                  Name Sex   Age  Height  Weight         Team  NOC  \
# 32   13    Minna Maarit Aalto   F  30.0   159.0    55.5      Finland  FIN
# 92   30      Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands  NED
# 97   33   Mika Lauri Aarnikka   M  28.0   187.0    76.0      Finland  FIN
# 100  36  Stefan Remco Aartsen   M  21.0   194.0    78.0  Netherlands  NED
# 101  36  Stefan Remco Aartsen   M  21.0   194.0    78.0  Netherlands  NED
#
#            Games  Year  Season     City     Sport  \
# 32   1996 Summer  1996  Summer  Atlanta   Sailing
# 92   1996 Summer  1996  Summer  Atlanta    Rowing
# 97   1996 Summer  1996  Summer  Atlanta   Sailing
# 100  1996 Summer  1996  Summer  Atlanta  Swimming
# 101  1996 Summer  1996  Summer  Atlanta  Swimming
#
#                                       Event   Medal
# 32               Sailing Women's Windsurfer     NaN
# 92   Rowing Men's Lightweight Double Sculls  Silver
# 97          Sailing Men's Two Person Dinghy     NaN
# ...

# %%
year_1996_male = year_1996[year_1996["Sex"] == "M"]
year_1996_male.head()
# Out:
#      ID                  Name Sex   Age  Height  Weight         Team  NOC  \
# 92   30      Pepijn Aardewijn   M  26.0   189.0    72.0  Netherlands  NED
# 97   33   Mika Lauri Aarnikka   M  28.0   187.0    76.0      Finland  FIN
# 100  36  Stefan Remco Aartsen   M  21.0   194.0    78.0  Netherlands  NED
# 101  36  Stefan Remco Aartsen   M  21.0   194.0    78.0  Netherlands  NED
# 102  36  Stefan Remco Aartsen   M  21.0   194.0    78.0  Netherlands  NED
#
#            Games  Year  Season     City     Sport  \
# 92   1996 Summer  1996  Summer  Atlanta    Rowing
# 97   1996 Summer  1996  Summer  Atlanta   Sailing
# 100  1996 Summer  1996  Summer  Atlanta  Swimming
# 101  1996 Summer  1996  Summer  Atlanta  Swimming
# 102  1996 Summer  1996  Summer  Atlanta  Swimming
#
#                                           Event   Medal
# 92       Rowing Men's Lightweight Double Sculls  Silver
# 97              Sailing Men's Two Person Dinghy     NaN
# ...

# %%
year_1996_male['Sex'].value_counts()
# Out:
# M    8772
# Name: Sex, dtype: int64

# %%
year_1996['Year'].value_counts()
# Out:
# 1996    13780
# Name: Year, dtype: int64

# %%
year_1996_female = year_1996[year_1996["Sex"] == "F"]
year_1996_female.head()
# Out:
#       ID                     Name Sex   Age  Height  Weight       Team  NOC  \
# 32    13       Minna Maarit Aalto   F  30.0   159.0    55.5    Finland  FIN
# 105   37       Ann Kristin Aarnes   F  23.0   182.0    64.0     Norway  NOR
# 280  147            Joanne Abbott   F  41.0   160.0    57.0     Canada  CAN
# 579  332         Zarinah Abdullah   F  25.0     NaN     NaN  Singapore  SGP
# 719  410  Edwige Marie Abna Fouda   F  23.0   173.0    61.0   Cameroon  CMR
#
#            Games  Year  Season     City      Sport  \
# 32   1996 Summer  1996  Summer  Atlanta    Sailing
# 105  1996 Summer  1996  Summer  Atlanta   Football
# 280  1996 Summer  1996  Summer  Atlanta    Sailing
# 579  1996 Summer  1996  Summer  Atlanta  Badminton
# 719  1996 Summer  1996  Summer  Atlanta  Athletics
#
#                                       Event   Medal
# 32               Sailing Women's Windsurfer     NaN
# 105               Football Women's Football  Bronze
# ...

# %%
year_1996_female['Sex'].value_counts()
# Out:
# F    5008
# Name: Sex, dtype: int64

# %% [markdown]
# #### Details Dataset
# * year_1996
# * year_1996_male
# * year_1996_female

# %%
year_1996_male['Age'].value_counts().sort_index()
# Out:
# 14.0      1
# 15.0      7
# 16.0     23
# 17.0     98
# 18.0    166
# 19.0    331
# 20.0    455
# 21.0    648
# 22.0    781
# 23.0    886
# 24.0    821
# 25.0    684
# 26.0    720
# 27.0    603
# 28.0    525
# 29.0    407
# 30.0    340
# 31.0    249
# 32.0    223
# 33.0    158
# 34.0    148
# 35.0    106
# 36.0     66
# 37.0     56
# 38.0     42
# 39.0     43
# 40.0     36
# 41.0     18
# 42.0     23
# 43.0     19
# 44.0     14
# 45.0     22
# 46.0     11
# 47.0      3
# 48.0      5
# 49.0      4
# 50.0      5
# 51.0      2
# 53.0      6
# 54.0      2
# 56.0      2
# 59.0      1
# 62.0      2
# 63.0      4
# Name: Age, dtype: int64

# %% [markdown]
# #### Result
#
# * Youngest 1996 male participant = 14 years

# %%
year_1996_male[year_1996_male['Age'] == 14]
# Out:
#           ID             Name Sex   Age  Height  Weight         Team  NOC  \
# 87416  44326  Gwon Gyeong-Min   M  14.0   165.0    60.0  South Korea  KOR
#
#              Games  Year  Season     City   Sport                  Event Medal
# 87416  1996 Summer  1996  Summer  Atlanta  Diving  Diving Men's Platform   NaN

# %%
year_1996_female['Age'].value_counts().sort_index()
# Out:
# 12.0      1
# 13.0      8
# 14.0     54
# 15.0    219
# 16.0    244
# 17.0    261
# 18.0    277
# 19.0    234
# 20.0    270
# 21.0    339
# 22.0    314
# 23.0    332
# 24.0    369
# 25.0    320
# 26.0    308
# 27.0    307
# 28.0    221
# 29.0    196
# 30.0    156
# 31.0    147
# 32.0    104
# 33.0     81
# 34.0     59
# 35.0     48
# 36.0     31
# 37.0     31
# 38.0     18
# 39.0      8
# 40.0      5
# 41.0     10
# 42.0      4
# 43.0      4
# 44.0      4
# 45.0      5
# 47.0      2
# 48.0      2
# 49.0      2
# 50.0      4
# 51.0      3
# 54.0      2
# 58.0      2
# Name: Age, dtype: int64

# %% [markdown]
# #### Result
#
# Youngest 1996 female participant = 12 years

# %% [markdown]
# ### 2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.

# %%
year_2000 = data[data['Year'] == 2000]
year_2000.head()
# Out:
#     ID                  Name Sex   Age  Height  Weight         Team  NOC  \
# 31  12     Jyri Tapani Aalto   M  31.0   172.0    70.0      Finland  FIN
# 33  13    Minna Maarit Aalto   F  34.0   159.0    55.5      Finland  FIN
# 57  18  Timo Antero Aaltonen   M  31.0   189.0   130.0      Finland  FIN
# 81  23           Fritz Aanes   M  22.0   187.0    89.0       Norway  NOR
# 93  30      Pepijn Aardewijn   M  30.0   189.0    72.0  Netherlands  NED
#
#           Games  Year  Season    City      Sport  \
# 31  2000 Summer  2000  Summer  Sydney  Badminton
# 33  2000 Summer  2000  Summer  Sydney    Sailing
# 57  2000 Summer  2000  Summer  Sydney  Athletics
# 81  2000 Summer  2000  Summer  Sydney  Wrestling
# 93  2000 Summer  2000  Summer  Sydney     Rowing
#
#                                              Event Medal
# 31                         Badminton Men's Singles   NaN
# 33                      Sailing Women's Windsurfer   NaN
# ...

# %%
year_2000_male = year_2000[year_2000['Sex'] == "M"]
year_2000_male.head()
# Out:
#      ID                  Name Sex   Age  Height  Weight         Team  NOC  \
# 31   12     Jyri Tapani Aalto   M  31.0   172.0    70.0      Finland  FIN
# 57   18  Timo Antero Aaltonen   M  31.0   189.0   130.0      Finland  FIN
# 81   23           Fritz Aanes   M  22.0   187.0    89.0       Norway  NOR
# 93   30      Pepijn Aardewijn   M  30.0   189.0    72.0  Netherlands  NED
# 103  36  Stefan Remco Aartsen   M  25.0   194.0    78.0  Netherlands  NED
#
#            Games  Year  Season    City      Sport  \
# 31   2000 Summer  2000  Summer  Sydney  Badminton
# 57   2000 Summer  2000  Summer  Sydney  Athletics
# 81   2000 Summer  2000  Summer  Sydney  Wrestling
# 93   2000 Summer  2000  Summer  Sydney     Rowing
# 103  2000 Summer  2000  Summer  Sydney   Swimming
#
#                                               Event Medal
# 31                          Badminton Men's Singles   NaN
# 57                         Athletics Men's Shot Put   NaN
# ...

# %%
year_2000_male_unique = year_2000_male.drop_duplicates(subset=['Name'])
year_2000_male_unique.shape[0]
# Out:
# 6576

# %% [markdown]
# #### Result
#
# Unique Male Participants of 2000 olympics = 6576

# %%
gymnastics = year_2000_male_unique[year_2000_male_unique['Sport'] == "Gymnastics"]
gymnastics.shape[0]
# Out:
# 97

# %% [markdown]
# #### Result
#
# Unique Male Gymnastics of 2000 olympics = 97

# %% [markdown]
# #### Calculation:
#
# $$ Total-Male-Gymnastics / Total-Male-Participants-of-2000-olympics  $$

# %%
print("Percentage %.1f" %(97/6576 * 100))
# Out:
# Percentage 1.5

# %% [markdown]
# ### 3. What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal

# %%
year_2000 = data[data['Year'] == 2000]
year_2000.head()
# Out:
#     ID                  Name Sex   Age  Height  Weight         Team  NOC  \
# 31  12     Jyri Tapani Aalto   M  31.0   172.0    70.0      Finland  FIN
# 33  13    Minna Maarit Aalto   F  34.0   159.0    55.5      Finland  FIN
# 57  18  Timo Antero Aaltonen   M  31.0   189.0   130.0      Finland  FIN
# 81  23           Fritz Aanes   M  22.0   187.0    89.0       Norway  NOR
# 93  30      Pepijn Aardewijn   M  30.0   189.0    72.0  Netherlands  NED
#
#           Games  Year  Season    City      Sport  \
# 31  2000 Summer  2000  Summer  Sydney  Badminton
# 33  2000 Summer  2000  Summer  Sydney    Sailing
# 57  2000 Summer  2000  Summer  Sydney  Athletics
# 81  2000 Summer  2000  Summer  Sydney  Wrestling
# 93  2000 Summer  2000  Summer  Sydney     Rowing
#
#                                              Event Medal
# 31                         Badminton Men's Singles   NaN
# 33                      Sailing Women's Windsurfer   NaN
# ...

# %%
year_2000_female = year_2000[year_2000['Sex'] == "F"]
year_2000_female.head()
# Out:
#       ID                Name Sex   Age  Height  Weight        Team  NOC  \
# 33    13  Minna Maarit Aalto   F  34.0   159.0    55.5     Finland  FIN
# 259  131       Tran Abbasova   F  33.0   159.0    53.0  Azerbaijan  AZE
# 329  180    Heba Abdel Gawad   F  18.0   154.0    48.0       Egypt  EGY
# 331  181    Sara Abdel Gawad   F  18.0   153.0    46.0       Egypt  EGY
# 498  277  Shaimaa Abdul Aziz   F  19.0   160.0    53.0       Egypt  EGY
#
#            Games  Year  Season    City                  Sport  \
# 33   2000 Summer  2000  Summer  Sydney                Sailing
# 259  2000 Summer  2000  Summer  Sydney          Weightlifting
# 329  2000 Summer  2000  Summer  Sydney  Synchronized Swimming
# 331  2000 Summer  2000  Summer  Sydney  Synchronized Swimming
# 498  2000 Summer  2000  Summer  Sydney           Table Tennis
#
#                                    Event Medal
# 33            Sailing Women's Windsurfer   NaN
# 259  Weightlifting Women's Featherweight   NaN
# ...

# %%
year_2000_female_basketball = year_2000_female[year_2000_female['Sport'] == "Basketball"]
year_2000_female_basketball.head()
# Out:
#         ID                               Name Sex   Age  Height  Weight  \
# 1034   580       Svetlana Olegovna Abrosimova   F  20.0   188.0    77.0
# 1857  1020       Adriana Aparecida dos Santos   F  29.0   180.0    61.0
# 1863  1023   Adriana "Adrianinha" Moiss Pinto   F  21.0   170.0    65.0
# 4458  2546  Alessandra dos Santos de Oliveira   F  26.0   200.0    85.0
# 8185  4516                      Nicole Antibe   F  26.0   187.0    83.0
#
#         Team  NOC        Games  Year  Season    City       Sport  \
# 1034  Russia  RUS  2000 Summer  2000  Summer  Sydney  Basketball
# 1857  Brazil  BRA  2000 Summer  2000  Summer  Sydney  Basketball
# 1863  Brazil  BRA  2000 Summer  2000  Summer  Sydney  Basketball
# 4458  Brazil  BRA  2000 Summer  2000  Summer  Sydney  Basketball
# 8185  France  FRA  2000 Summer  2000  Summer  Sydney  Basketball
#
#                               Event   Medal
# 1034  Basketball Women's Basketball     NaN
# 1857  Basketball Women's Basketball  Bronze
# ...

# %%
year_2000_female_basketball.shape
# Out:
# (142, 15)

# %%
year_2000_female_basketball_unique = year_2000_female_basketball.drop_duplicates(subset=['Name'])
year_2000_female_basketball_unique.shape
# Out:
# (142, 15)

# %%
year_2000_female_basketball_unique['Height'].mean()
# Out:
# 182.38732394366198

# %%
year_2000_female_basketball_unique['Height'].std()
# Out:
# 9.139462087892174

# %% [markdown]
# ### Result:
#
# * Mean = 182.4
# * Standard Deviation = 9.1

# %% [markdown]
# ### 4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?

# %%
year_2002 = data[data['Year'] == 2002]
year_2002.head()
# Out:
#     ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 28   9    Antti Sami Aalto   M  26.0   186.0    96.0  Finland  FIN
# 72  20  Kjetil Andr Aamodt   M  30.0   176.0    85.0   Norway  NOR
# 73  20  Kjetil Andr Aamodt   M  30.0   176.0    85.0   Norway  NOR
# 74  20  Kjetil Andr Aamodt   M  30.0   176.0    85.0   Norway  NOR
# 75  20  Kjetil Andr Aamodt   M  30.0   176.0    85.0   Norway  NOR
#
#           Games  Year  Season            City          Sport  \
# 28  2002 Winter  2002  Winter  Salt Lake City     Ice Hockey
# 72  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 73  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 74  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
# 75  2002 Winter  2002  Winter  Salt Lake City  Alpine Skiing
#
#                                Event Medal
# 28       Ice Hockey Men's Ice Hockey   NaN
# 72      Alpine Skiing Men's Downhill   NaN
# 73       Alpine Skiing Men's Super G  Gold
# ...

# %%
year_2002['Weight'].value_counts().sort_index().tail()
# Out:
# 112.0    1
# 113.0    2
# 115.0    1
# 116.0    1
# 123.0    1
# Name: Weight, dtype: int64

# %%
sportsmen = year_2002[year_2002['Weight'] == 123]
sportsmen.head()
# Out:
#           ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 99154  50171  Emmanuel Hostache   M  26.0   190.0   123.0  France  FRA
#
#              Games  Year  Season            City      Sport  \
# 99154  2002 Winter  2002  Winter  Salt Lake City  Bobsleigh
#
#                      Event Medal
# 99154  Bobsleigh Men's Two   NaN

# %% [markdown]
# #### Result:
#
# Sports is Bobsleigh.

# %% [markdown]
# #### 5. How many times did Pawe Abratkiewicz participate in the Olympics held in different years?

# %%
pawe = data[data['Name'] == "Pawe Abratkiewicz"]
pawe
# Out:
#        ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 997   562  Pawe Abratkiewicz   M  21.0   183.0    84.0  Poland  POL
# 998   562  Pawe Abratkiewicz   M  21.0   183.0    84.0  Poland  POL
# 999   562  Pawe Abratkiewicz   M  27.0   183.0    84.0  Poland  POL
# 1000  562  Pawe Abratkiewicz   M  27.0   183.0    84.0  Poland  POL
# 1001  562  Pawe Abratkiewicz   M  31.0   183.0    84.0  Poland  POL
# 1002  562  Pawe Abratkiewicz   M  31.0   183.0    84.0  Poland  POL
#
#             Games  Year  Season            City          Sport  \
# 997   1992 Winter  1992  Winter     Albertville  Speed Skating
# 998   1992 Winter  1992  Winter     Albertville  Speed Skating
# 999   1998 Winter  1998  Winter          Nagano  Speed Skating
# 1000  1998 Winter  1998  Winter          Nagano  Speed Skating
# 1001  2002 Winter  2002  Winter  Salt Lake City  Speed Skating
# 1002  2002 Winter  2002  Winter  Salt Lake City  Speed Skating
#
# ...

# %%
pawe['Year'].value_counts()
# Out:
# 1998    2
# 2002    2
# 1992    2
# Name: Year, dtype: int64

# %% [markdown]
# #### Result:
#
# Participated in 3 different years i.e. 1998, 2002, and 1992.

# %% [markdown]
# #### 6. How many silver medals in tennis did Australia win at the 2000 Olympics?

# %%
silver_2000 = data[data['Year'] == 2000]
silver_2000.head()
# Out:
#     ID                  Name Sex   Age  Height  Weight         Team  NOC  \
# 31  12     Jyri Tapani Aalto   M  31.0   172.0    70.0      Finland  FIN
# 33  13    Minna Maarit Aalto   F  34.0   159.0    55.5      Finland  FIN
# 57  18  Timo Antero Aaltonen   M  31.0   189.0   130.0      Finland  FIN
# 81  23           Fritz Aanes   M  22.0   187.0    89.0       Norway  NOR
# 93  30      Pepijn Aardewijn   M  30.0   189.0    72.0  Netherlands  NED
#
#           Games  Year  Season    City      Sport  \
# 31  2000 Summer  2000  Summer  Sydney  Badminton
# 33  2000 Summer  2000  Summer  Sydney    Sailing
# 57  2000 Summer  2000  Summer  Sydney  Athletics
# 81  2000 Summer  2000  Summer  Sydney  Wrestling
# 93  2000 Summer  2000  Summer  Sydney     Rowing
#
#                                              Event Medal
# 31                         Badminton Men's Singles   NaN
# 33                      Sailing Women's Windsurfer   NaN
# ...

# %%
silver_2000_tennis = silver_2000[silver_2000['Sport'] == "Tennis"]
silver_2000_tennis.head()
# Out:
#         ID                            Name Sex   Age  Height  Weight  \
# 184     82          Enrique Abaroa Martnez   M  26.0   183.0    75.0
# 1457   812               David Dixie Adams   M  30.0   188.0    79.0
# 3874  2235                     Karim Alami   M  27.0   185.0    85.0
# 6533  3659                       Mario Ani   M  16.0   195.0    84.0
# 8604  4723  Sabine Appelmans (-Haubourdin)   F  28.0   169.0    60.0
#
#               Team  NOC        Games  Year  Season    City   Sport  \
# 184         Mexico  MEX  2000 Summer  2000  Summer  Sydney  Tennis
# 1457  South Africa  RSA  2000 Summer  2000  Summer  Sydney  Tennis
# 3874       Morocco  MAR  2000 Summer  2000  Summer  Sydney  Tennis
# 6533       Croatia  CRO  2000 Summer  2000  Summer  Sydney  Tennis
# 8604       Belgium  BEL  2000 Summer  2000  Summer  Sydney  Tennis
#
#                        Event Medal
# 184     Tennis Men's Doubles   NaN
# 1457    Tennis Men's Doubles   NaN
# 3874    Tennis Men's Singles   NaN
# ...

# %%
silver_2000_tennis_aust = silver_2000_tennis[silver_2000_tennis['Team'] == "Australia"]
silver_2000_tennis_aust.head()
# Out:
#            ID                  Name Sex   Age  Height  Weight       Team  NOC  \
# 56848   29135          Jelena Dokic   F  17.0   175.0    57.0  Australia  AUS
# 56849   29135          Jelena Dokic   F  17.0   175.0    57.0  Australia  AUS
# 95493   48346  Lleyton Glynn Hewitt   M  19.0   180.0    68.0  Australia  AUS
# 102491  51842           Andrew Ilie   M  24.0   182.0    73.0  Australia  AUS
# 161587  81119          Alicia Molik   F  19.0   182.0    78.0  Australia  AUS
#
#               Games  Year  Season    City   Sport                   Event  \
# 56848   2000 Summer  2000  Summer  Sydney  Tennis  Tennis Women's Singles
# 56849   2000 Summer  2000  Summer  Sydney  Tennis  Tennis Women's Doubles
# 95493   2000 Summer  2000  Summer  Sydney  Tennis    Tennis Men's Singles
# 102491  2000 Summer  2000  Summer  Sydney  Tennis    Tennis Men's Singles
# 161587  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Women's Singles
#
#        Medal
# 56848    NaN
# 56849    NaN
# ...

# %%
silver_2000_tennis_aust['Medal'].value_counts()
# Out:
# Silver    2
# Name: Medal, dtype: int64

# %% [markdown]
# #### Result:
#
# 2 Silver medals.

# %% [markdown]
# ### 7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in Medal column.

# %%
year_2016 = data[data['Year'] == 2016]
year_2016.head()
# Out:
#      ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 80   22      Andreea Aanei   F  22.0   170.0   125.0  Romania  ROU
# 139  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 140  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 141  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 142  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
#
#            Games  Year  Season            City          Sport  \
# 80   2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 139  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 140  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 141  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 142  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                        Event Medal
# 80   Weightlifting Women's Super-Heavyweight   NaN
# 139   Gymnastics Men's Individual All-Around   NaN
# ...

# %%
year_2016_swit = year_2016[year_2016['Team'] == "Switzerland"]
year_2016_swit.head()
# Out:
#          ID              Name Sex   Age  Height  Weight         Team  NOC  \
# 894     511   Tadesse Abraham   M  33.0   178.0    61.0  Switzerland  SUI
# 3999   2304  Michael Albasini   M  35.0   172.0    67.0  Switzerland  SUI
# 7986   4422     Jolanda Annen   F  23.0   166.0    56.0  Switzerland  SUI
# 10582  5783       Sarah Atcho   F  21.0   180.0    63.0  Switzerland  SUI
# 12202  6632  Timea Bacsinszky   F  27.0   170.0    62.0  Switzerland  SUI
#
#              Games  Year  Season            City      Sport  \
# 894    2016 Summer  2016  Summer  Rio de Janeiro  Athletics
# 3999   2016 Summer  2016  Summer  Rio de Janeiro    Cycling
# 7986   2016 Summer  2016  Summer  Rio de Janeiro  Triathlon
# 10582  2016 Summer  2016  Summer  Rio de Janeiro  Athletics
# 12202  2016 Summer  2016  Summer  Rio de Janeiro     Tennis
#
#                                         Event Medal
# 894                  Athletics Men's Marathon   NaN
# 3999      Cycling Men's Road Race, Individual   NaN
# ...

# %%
year_2016_swit['Medal'].value_counts()
# Out:
# Gold      6
# Silver    3
# Bronze    2
# Name: Medal, dtype: int64

# %%
year_2016_serb = year_2016[year_2016['Team'] == "Serbia"]
year_2016_serb.head()
# Out:
#         ID            Name Sex   Age  Height  Weight    Team  NOC  \
# 4417  2517    Milan Aleksi   M  30.0   193.0    96.0  Serbia  SRB
# 9754  5346   Andrea Arsovi   F  29.0   165.0    61.0  Serbia  SRB
# 9755  5346   Andrea Arsovi   F  29.0   165.0    61.0  Serbia  SRB
# 9880  5406  Zorana Arunovi   F  29.0   168.0    90.0  Serbia  SRB
# 9881  5406  Zorana Arunovi   F  29.0   168.0    90.0  Serbia  SRB
#
#             Games  Year  Season            City       Sport  \
# 4417  2016 Summer  2016  Summer  Rio de Janeiro  Water Polo
# 9754  2016 Summer  2016  Summer  Rio de Janeiro    Shooting
# 9755  2016 Summer  2016  Summer  Rio de Janeiro    Shooting
# 9880  2016 Summer  2016  Summer  Rio de Janeiro    Shooting
# 9881  2016 Summer  2016  Summer  Rio de Janeiro    Shooting
#
#                                                   Event Medal
# 4417                        Water Polo Men's Water Polo  Gold
# 9754              Shooting Women's Air Rifle, 10 metres   NaN
# ...

# %%
year_2016_serb['Medal'].value_counts()
# Out:
# Silver    27
# Gold      14
# Bronze    13
# Name: Medal, dtype: int64

# %% [markdown]
# ### Result:
#
# Yes

# %% [markdown]
# ### 8. What age category did the fewest and the most participants of the 2014 Olympics belong to?

# %%
year_2014 = data[data['Year'] == 2014]
year_2014.head()
# Out:
#       ID                      Name Sex   Age  Height  Weight           Team  \
# 40    16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0        Finland
# 252  126            Forough Abbasi   F  20.0   164.0    58.0           Iran
# 277  145             Jeremy Abbott   M  28.0   175.0    70.0  United States
# 278  145             Jeremy Abbott   M  28.0   175.0    70.0  United States
# 809  463             Agnese boltia   F  17.0   166.0    60.0         Latvia
#
#      NOC        Games  Year  Season   City           Sport  \
# 40   FIN  2014 Winter  2014  Winter  Sochi      Ice Hockey
# 252  IRI  2014 Winter  2014  Winter  Sochi   Alpine Skiing
# 277  USA  2014 Winter  2014  Winter  Sochi  Figure Skating
# 278  USA  2014 Winter  2014  Winter  Sochi  Figure Skating
# 809  LAT  2014 Winter  2014  Winter  Sochi   Alpine Skiing
#
#                              Event   Medal
# 40     Ice Hockey Men's Ice Hockey  Bronze
# 252   Alpine Skiing Women's Slalom     NaN
# ...

# %%
year_2014['Age'].value_counts().sort_index().plot.bar(figsize=(10,6))

# %% [markdown]
# ### Result:
#
# [45-55] and [25-35]

# %% [markdown]
# ### 9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?

# %%
summer = data[data["Season"] == "Summer"]
summer.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal
# 0    Basketball Men's Basketball   NaN
# ...

# %%
winter = data[data['Season'] == "Winter"]
winter.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight         Team  NOC  \
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
#
#          Games  Year  Season         City          Sport  \
# 4  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# ...

# %%
summer['City'].value_counts()
# Out:
# London            22426
# Athina            15556
# Sydney            13821
# Atlanta           13780
# Rio de Janeiro    13688
# Beijing           13602
# Barcelona         12977
# Los Angeles       12423
# Seoul             12037
# Munich            10304
# Montreal           8641
# Mexico City        8588
# Helsinki           8270
# Roma               8119
# Tokyo              7702
# Moskva             7191
# Paris              7169
# Berlin             6506
# Amsterdam          4992
# Melbourne          4829
# Stockholm          4338
# Antwerpen          4292
# St. Louis          1301
# Name: City, dtype: int64

# %%
winter['City'].value_counts()
# Out:
# Sochi                     4891
# Vancouver                 4402
# Torino                    4382
# Salt Lake City            4109
# Innsbruck                 3639
# Nagano                    3605
# Albertville               3436
# Lillehammer               3160
# Calgary                   2639
# Sarajevo                  2134
# Lake Placid               2098
# Grenoble                  1891
# Sankt Moritz              1657
# Sapporo                   1655
# Cortina d'Ampezzo         1307
# Squaw Valley              1116
# Oslo                      1088
# Garmisch-Partenkirchen     895
# Chamonix                   460
# Name: City, dtype: int64

# %% [markdown]
# ### Result:
#
# No, Yes

# %% [markdown]
# ### 10. What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?

# %%
year_2016 = data[data["Year"] == 2016]
year_2016.head()
# Out:
#      ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 80   22      Andreea Aanei   F  22.0   170.0   125.0  Romania  ROU
# 139  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 140  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 141  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
# 142  51  Nstor Abad Sanjun   M  23.0   167.0    64.0    Spain  ESP
#
#            Games  Year  Season            City          Sport  \
# 80   2016 Summer  2016  Summer  Rio de Janeiro  Weightlifting
# 139  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 140  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 141  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
# 142  2016 Summer  2016  Summer  Rio de Janeiro     Gymnastics
#
#                                        Event Medal
# 80   Weightlifting Women's Super-Heavyweight   NaN
# 139   Gymnastics Men's Individual All-Around   NaN
# ...

# %%
len(list(year_2016['Sport'].value_counts()))
# Out:
# 34

# %% [markdown]
# ### Result:
# There is no olympics played in 1995.
#
# difference = 34
